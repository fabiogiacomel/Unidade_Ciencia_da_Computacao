# %% [markdown]
# # 📓 Meu Caderno de Campo Digital
#
# **Aluno:** [Seu Nome Aqui]
# **Curso:** Ciência da Computação
#
# ---
#
# ## 💡 Como usar este caderno?
# Este é o seu **Diário de Bordo**. Use-o para registrar tudo o que você aprender.
# Você pode misturar **Texto** (para explicações) e **Código** (para testar na hora!).
#
# ---

# %% [markdown]
# ## 📅 Data: [Data de Hoje] - Aula: [Título da Aula]
#
# ### 1. O que eu aprendi hoje?
# *(Escreva aqui com suas palavras. Ex: Hoje aprendi que variáveis são caixinhas...)*

# %% [markdown]
# ### 2. Meus Experimentos de Código
# *(Use a célula abaixo para colar o código da aula e modificar os valores)*

# %%
# Cole seu código Python aqui e aperte o Play ▶️
print("Olá, este é meu primeiro experimento!")

# %% [markdown]
# ### 3. Diário de Erros (Bugs) 🐛
# *(Se algo deu errado, anote aqui. Errar faz parte de aprender!)*
# - **Erro:** ...
# - **Solução:** ...

# %% [markdown]
# ---
# *(Copie e cole a estrutura acima para a próxima aula)*
